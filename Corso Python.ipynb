# %% [markdown]
# Corso Python
# =======

# %% [markdown]
# ### Documentazione
#
# **Online** potete trovare _esempi_, _tutorial_ e _guide_ molto approfondite. Se volete un punto di partenza vi consiglio:
#
# 1. [https://docs.python.org/3/tutorial/index.html](https://docs.python.org/3/tutorial/index.html)
# 2. [versione italiana del libro di Allen Downey 'Think Python'](https://github.com/AllenDowney/ThinkPythonItalian/blob/master/thinkpython_italian.pdf)
#
# Se volete scaricarvi Python per iniziare a sperimentare, partite da **Anaconda**
#
# [www.anaconda.com/download](www.anaconda.com/download)

# %% [markdown]
# ### Lezione 1
#
# - Introduzione
# - Il primo programma
# - Operatori Aritmetici
# - Valori e tipi
#
#
# - I plot!

# %%
print('Hello, World!')
# Out:
# Hello, World!

# %%
# Commento!

# posso usare python come calcolatrice

2+2
# Out:
# 4

# %%
3**2
# Out:
# 9

# %%
print(type(1))
print(type('ciao'))
print(type(1.4))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %% [markdown]
# ### Qualcosa di più interessante: i plot

# %%
import matplotlib.pyplot as plt
import numpy as np


# %matplotlib inline

x = np.linspace(0, 3*np.pi, 500)
plt.plot(x, np.sin(x**2))
plt.title('Un semplice plot');

# %%
plt.figure()
x = np.linspace(0, 5 * np.pi, 1000)
for n in range(1, 4):
    plt.plot(np.sin(n * x))
plt.show()

# %% [markdown]
# Disegnare il **grafico** di una funzione:

# %%
x = np.linspace(0, 5, 10)
y = x ** 2

plt.figure()
plt.plot(x, y, 'r')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Titolo')
plt.show()

# %% [markdown]
# Più raffinati? ecco i **subplot**

# %%
plt.subplot(1,2,1)
plt.plot(x, y, 'r--')
plt.subplot(1,2,2)
plt.plot(y, x, 'g*-');

# %% [markdown]
# Plot di più funzioni insieme

# %%
fig, ax = plt.subplots()

ax.plot(x, x**2, label="y = x**2")
ax.plot(x, x**3, label="y = x**3")
ax.legend(loc=2); # upper left corner
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_title('title');

# %% [markdown]
# Aggiungiamo qualcosa scritta in **Latex**

# %%
fig, ax = plt.subplots()

ax.plot(x, x**2, label=r"$y = \alpha^2$")
ax.plot(x, x**3, label=r"$y = \alpha^3$")
ax.legend(loc=2) # upper left corner
ax.set_xlabel(r'$\alpha$', fontsize=18)
ax.set_ylabel(r'$y$', fontsize=18)
ax.set_title('title');

# %% [markdown]
# Complichiamo ancora di più!

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon


def func(x):
    return (x - 3) * (x - 5) * (x - 7) + 85


a, b = 2, 9 # integral limits
x = np.linspace(0, 10)
y = func(x)

fig, ax = plt.subplots()
plt.plot(x, y, 'r', linewidth=2)
plt.ylim(ymin=0)

# Make the shaded region
ix = np.linspace(a, b)
iy = func(ix)
verts = [(a, 0)] + list(zip(ix, iy)) + [(b, 0)]
poly = Polygon(verts, facecolor='0.9', edgecolor='0.5')
ax.add_patch(poly)

plt.text(0.5 * (a + b), 30, r"$\int_a^b f(x)\mathrm{d}x$",
         horizontalalignment='center', fontsize=20)

plt.figtext(0.9, 0.05, '$x$')
plt.figtext(0.1, 0.9, '$y$')

ax.spines['right'].set_visible(False)
ax.spines['top'].set_visible(False)
ax.xaxis.set_ticks_position('bottom')

ax.set_xticks((a, b))
ax.set_xticklabels(('$a$', '$b$'))
ax.set_yticks([])

plt.show()

# %% [markdown]
# ### Lezione - Le basi - liste dizionari set tuple

# %% [markdown]
# ### Lezione - i cicli

# %% [markdown]
# ### Lezione - numpy

# %% [markdown]
# ### Lezione - simpy

# %% [markdown]
# ### Lezione - matplotlib
